# %%
import pandas as pd
import re

# %%
with open('data/Reglamento Estudiantil_documento_34866874.txt') as f:
    data = f.read().splitlines()

# %%
# Initialize the dictionary to store the reglamento
reglamento = {}
current_title = None
current_chapter = 'CAPÍTULO 0'
current_article = None
current_key = None
skip_lines = False

for line in data:
    line = line.strip()
    
    # Skip empty lines
    if not line:
        continue

    # Skip lines that are just numbers
    if line.isdigit():
        continue
    
    # Check for "TÍTULO [NAME]"
    title_match = re.match(r'TÍTULO (.+)', line)
    if title_match:
        current_title = f'TÍTULO {title_match.group(1)}'
        reglamento[current_title] = {'CAPÍTULO 0': {}}
        current_chapter = 'CAPÍTULO 0'
        current_article = None
        current_key = None
        continue
    
    # Check for "CAPÍTULO [NAME]"
    chapter_match = re.match(r'CAPÍTULO (.+)', line)
    if chapter_match:
        current_chapter = f'CAPÍTULO {chapter_match.group(1)}'
        reglamento[current_title][current_chapter] = {}
        current_article = None
        current_key = None
        continue
    
    # Check for "ARTÍCULO [NUMBER]"
    article_match = re.match(r'ARTÍCULO (\d+)\.', line)
    if article_match:
        current_article = f'ARTÍCULO {article_match.group(1)}'
        reglamento[current_title][current_chapter][current_article] = {'texto': line[len(current_article) + 2:].strip()}
        current_key = 'texto'
        continue
    
    # Check for "Parágrafo [NUMBER]"
    paragrafo_match = re.match(r'Parágrafo (\d+)', line)
    if paragrafo_match:
        current_key = f'Parágrafo {paragrafo_match.group(1)}'
        reglamento[current_title][current_chapter][current_article][current_key] = line[len(current_key) + 1:].strip()
        continue
    
    # Check for "Literal [LETTER]"
    literal_match = re.match(r'([a-z])\.', line)
    if literal_match:
        current_key = f'Literal {literal_match.group(1)}'
        reglamento[current_title][current_chapter][current_article][current_key] = line[len(literal_match.group(1)) + 1:].strip()
        continue
    
    # Check for "Concordancias:" or "Reglamentación:"
    if line.startswith('Concordancias:') or line.startswith('Reglamentación:'):
        current_key = None
        skip_lines = True
        continue
    
    # Stop skipping lines when a new article, paragraph, or literal is found
    if skip_lines and (re.match(r'ARTÍCULO (\d+)\.', line) or re.match(r'Parágrafo (\d+)', line) or re.match(r'([a-z])\.', line)):
        skip_lines = False
    
    # Skip lines if skip_lines flag is set
    if skip_lines:
        continue
    
    # Append text to the current key if it exists
    if current_key and current_article and current_key in reglamento[current_title][current_chapter][current_article]:
        reglamento[current_title][current_chapter][current_article][current_key] += ' ' + line

print(reglamento)
# Out:
# {'TÍTULO PRIMERO': {'CAPÍTULO 0': {'ARTÍCULO 1': {'texto': 'La Universidad de Antioquia como institución de servicio público, en cumplimiento de su función social, será siempre un centro de cultura y de ciencia que imparta a los estudiantes formación integral y los capacite para el ejercicio profesional en las diferentes áreas del quehacer humano.'}, 'ARTÍCULO 2': {'texto': 'La función esencial de la Universidad es la docente-investigativa en los', 'Literal a': 'Desarrollar en sus estudiantes una actitud científica y crítica que les permita tener', 'Literal b': 'Contribuir al desarrollo en el estudiante de habilidades que le permitan acceder al', 'Literal c': 'Proporcionar los elementos necesarios para entender la personal ubicación dentro de la'}, 'ARTÍCULO 3': {'texto': 'La función docente-investigativa estará encaminada, fundamentalmente,'}, 'ARTÍCULO 4': {'texto': 'El proceso de enseñanza aprendizaje, para el cumplimiento de la misión'}, 'ARTÍCULO 5': {'texto': 'Para cumplir su objetivo el proceso de formación debe desarrollarse'}, 'ARTÍCULO 6': {'texto': 'Se entiende por libertad de cátedra la discrecionalidad que tiene el'}, 'ARTÍCULO 7': {'texto': 'Se entiende por libertad de aprendizaje la que tiene el estudiante para'}, 'ARTÍCULO 8': {'texto': 'Dentro de los límites de la Constitución y la ley, la Universidad es'}, 'ARTÍCULO 9': {'texto': 'Como producto del trabajo armónico de toda la comunidad universitaria,'}, 'ARTÍCULO 10': {'texto': 'Como institución de educación superior, la Universidad promoverá el'}, 'ARTÍCULO 11': {'texto': 'Todos los integrantes de la comunidad universitaria tienen derecho a la'}, 'ARTÍCULO 12': {'texto': 'La participación de los estudiantes en los organismos de dirección y de'}, 'ARTÍCULO 13': {'texto': 'El acceso a la Universidad, en armonía con sus posibilidades no podrá'}, 'ARTÍCULO 14': {'texto': 'La Universidad promoverá constantemente la actualización de los'}, 'ARTÍCULO 15': {'texto': 'La Universidad desarrollará programas encaminados a propiciar el'}, 'ARTÍCULO 16': {'texto': 'La permanencia en la Universidad se fundamentará en dos condiciones:'}, 'ARTÍCULO 17': {'texto': 'El régimen académico, además de regular las relaciones entre los'}, 'ARTÍCULO 18': {'texto': 'Las normas disciplinarias procuran prevenir aquellas conductas'}, 'ARTÍCULO 19': {'texto': 'El presente título contiene los principios generales del reglamento'}}, 'CAPÍTULO I': {'ARTÍCULO 20': {'texto': '(Modificado por el AS 458/2019). Para efectos del presente reglamento,', 'Parágrafo 1': 'Las personas que ingresen a la universidad por los procesos de movilidad', 'Parágrafo 2': '(Adicionado por el AS 479/2022). El Consejo Académico reglamentará lo'}, 'ARTÍCULO 21': {'texto': '(Modificado por el AS 409/2013). La calidad de estudiante se adquiere'}, 'ARTÍCULO 22': {'texto': '(Modificado por el AS 409/2013). La calidad de estudiante se termina', 'Literal a': 'Cuando se haya completado el programa de formación previsto.', 'Literal b': 'Cuando no se haya hecho uso del derecho de renovación de la matrícula dentro de los', 'Literal c': 'Cuando se haya perdido el derecho a permanecer en la institución por inasistencia o', 'Literal d': 'Cuando se haya cancelado la matrícula por incumplimiento de las obligaciones', 'Literal e': 'Cuando haya habido expulsión.', 'Literal f': 'Cuando por motivos graves de salud, previo dictamen médico, se considere', 'Literal g': '(Adicionado por el AS 409 del 27 de agosto de 2013). Cuando se complete el plan de'}}, 'CAPÍTULO II': {'ARTÍCULO 23': {'texto': 'Un programa académico es el conjunto de cursos básicos, profesionales'}, 'ARTÍCULO 24': {'texto': 'En armonía con las normas legales se denomina título académico el'}, 'ARTÍCULO 25': {'texto': '(Modificado por el AS 459/2019). El Consejo Superior, por'}, 'ARTÍCULO 26': {'texto': 'Se denomina plan de estudios el conjunto de cursos obligatorios y', 'Parágrafo 1': '(Adicionado por el AS 259/1993). Los cursos de los Programas', 'Parágrafo 2': '(Adici ...

# %%
reglamento["TÍTULO PRIMERO"]["CAPÍTULO 0"]["ARTÍCULO 2"]["texto"]
# Out:
# 'La función esencial de la Universidad es la docente-investigativa en los'

# %%
data[]
